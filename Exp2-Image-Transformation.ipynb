# %% [markdown]
# ### **S Athisii Kayina**
# M.Tech AI 3rd Semester
#
# NDU202400088
#
# NIELIT-IMPHAL

# %% [markdown]
# # Experiment 2: Image Transformations
# Develop a Python program using OpenCV to implement geometric transformations including
# scaling, translation, and rotation. Display the original and transformed images.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load image
# !wget -q -O input.jpg https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg
image = cv2.imread('input.jpg')
rows, cols, _ = image.shape

print("Original Image")
cv2_imshow(image)


# SCALING

img_scaled = cv2.resize(image, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR) # scaling of 1.5

print("\n Scaled Image")
cv2_imshow(img_scaled)


# TRANSLATION

# Translation Matrix: T = [[1, 0, tx], [0, 1, ty]]
tx, ty = 100, 50
M_translation = np.float32([[1, 0, tx], [0, 1, ty]])
img_translated = cv2.warpAffine(image, M_translation, (cols, rows))

print(f"\n Translated Image ")
cv2_imshow(img_translated)


# ROTATION

# rotation of 45 degrees
center = (cols // 2, rows // 2)
M_rotation = cv2.getRotationMatrix2D(center, 45, 1.0) # (center, angle, scale)
img_rotated = cv2.warpAffine(image, M_rotation, (cols, rows))

print("\n Rotated Image")
cv2_imshow(img_rotated)
